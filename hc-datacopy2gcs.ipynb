# %% [markdown]
# **Moving kaggle datasets to specific Google Storage Bucket**
#
# Reference notebook : Click [here](http://www.kaggle.com/code/paultimothymooney/how-to-move-data-from-kaggle-to-gcs-and-back)

# %% [markdown]
# Import Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %% [markdown]
# Connect to GCS Storage Client

# %%
from google.cloud import storage
storage_client = storage.Client(project='kagglehomecredit')

# %% [markdown]
# Set dataset path

# %%
inputdatapath = '/kaggle/input/home-credit-credit-risk-model-stability/csv_files/'

# %%
for dirname, _, filenames in os.walk(inputdatapath):
    
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_6.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_11.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_9.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_base.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_b_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_10.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_4.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_cb_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_b_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_b_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_person_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_person_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_8.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_7.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_other_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_c_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_3.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_5.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_debitcard_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_4.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_deposit_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_a_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_3.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_3.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_cb_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_1_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_person_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_base.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_a_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_0_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_6.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_person_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_c_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_4.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_9.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_3.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_7.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_b_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_2.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_0_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_deposit_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_10.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_b_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_1_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_8.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_5.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_b_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_0.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_other_1.csv
# /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_debitcard_1.csv

# %% [markdown]
# Helper functions
# 1. Create Bucjet
# 2. Upload Files
# 3. List Files
# 4. Download to kaggle notebook

# %%
def create_bucket(dataset_name):
    """Creates a new bucket. https://cloud.google.com/storage/docs/ """
    bucket = storage_client.create_bucket(dataset_name)
    print('Bucket {} created'.format(bucket.name))

def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket. https://cloud.google.com/storage/docs/ """
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)
    print('File {} uploaded to {}.'.format(
        source_file_name,
        destination_blob_name))
    
def list_blobs(bucket_name):
    """Lists all the blobs in the bucket. https://cloud.google.com/storage/docs/"""
    blobs = storage_client.list_blobs(bucket_name)
    for blob in blobs:
        print(blob.name)
        
def download_to_kaggle(bucket_name,destination_directory,file_name):
    """Takes the data from your GCS Bucket and puts it into the working directory of your Kaggle notebook"""
    os.makedirs(destination_directory, exist_ok = True)
    full_file_path = os.path.join(destination_directory, file_name)
    blobs = storage_client.list_blobs(bucket_name)
    for blob in blobs:
        blob.download_to_filename(full_file_path)

# %% [markdown]
# Creates a GCS bucket if not existing

# %%
bucket_name = 'baglitech-kaggle-homecredit'         
try:
    create_bucket(bucket_name)   
except:
    pass

# %% [markdown]
# Loop the data path to upload all files in the datapath into GCS Bucket

# %%
# local_data = '/kaggle/input/breast-cancer-wisconsin-data/data.csv'
# file_name = 'data.csv' 

for dirname, _, filenames in os.walk(inputdatapath):
    
    for filename in filenames:
        filepath = os.path.join(dirname, filename)
        upload_blob(bucket_name, filepath, filename)
# Out:
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_6.csv uploaded to test_credit_bureau_a_2_6.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_11.csv uploaded to test_credit_bureau_a_2_11.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_0.csv uploaded to test_credit_bureau_a_2_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_9.csv uploaded to test_credit_bureau_a_2_9.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_base.csv uploaded to test_base.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_1.csv uploaded to test_credit_bureau_a_1_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_b_2.csv uploaded to test_credit_bureau_b_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_10.csv uploaded to test_credit_bureau_a_2_10.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_4.csv uploaded to test_credit_bureau_a_2_4.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_0.csv uploaded to test_static_0_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_cb_0.csv uploaded to test_static_cb_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_2.csv uploaded to test_credit_bureau_a_2_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_b_1.csv uploaded to test_credit_bureau_b_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_b_1.csv uploaded to test_tax_registry_b_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_person_2.csv uploaded to test_person_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_person_1.csv uploaded to test_person_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_8.csv uploaded to test_credit_bureau_a_2_8.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_2.csv uploaded to test_applprev_1_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_1.csv uploaded to test_applprev_1_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_0.csv uploaded to test_credit_bureau_a_1_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_2.csv uploaded to test_applprev_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_7.csv uploaded to test_credit_bureau_a_2_7.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_other_1.csv uploaded to test_other_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_c_1.csv uploaded to test_tax_registry_c_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_3.csv uploaded to test_credit_bureau_a_1_3.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_2.csv uploaded to test_static_0_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_5.csv uploaded to test_credit_bureau_a_2_5.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_2.csv uploaded to test_credit_bureau_a_1_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_debitcard_1.csv uploaded to test_debitcard_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_1_4.csv uploaded to test_credit_bureau_a_1_4.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_deposit_1.csv uploaded to test_deposit_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_static_0_1.csv uploaded to test_static_0_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_1.csv uploaded to test_credit_bureau_a_2_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_applprev_1_0.csv uploaded to test_applprev_1_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_tax_registry_a_1.csv uploaded to test_tax_registry_a_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_credit_bureau_a_2_3.csv uploaded to test_credit_bureau_a_2_3.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_3.csv uploaded to train_credit_bureau_a_1_3.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_cb_0.csv uploaded to train_static_cb_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_1_0.csv uploaded to train_applprev_1_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_person_2.csv uploaded to train_person_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_base.csv uploaded to train_base.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_a_1.csv uploaded to train_tax_registry_a_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_0_0.csv uploaded to train_static_0_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_0.csv uploaded to train_credit_bureau_a_1_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_2.csv uploaded to train_applprev_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_6.csv uploaded to train_credit_bureau_a_2_6.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_2.csv uploaded to train_credit_bureau_a_1_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_person_1.csv uploaded to train_person_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_1_1.csv uploaded to train_credit_bureau_a_1_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_c_1.csv uploaded to train_tax_registry_c_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_4.csv uploaded to train_credit_bureau_a_2_4.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_9.csv uploaded to train_credit_bureau_a_2_9.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_3.csv uploaded to train_credit_bureau_a_2_3.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_7.csv uploaded to train_credit_bureau_a_2_7.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_b_2.csv uploaded to train_credit_bureau_b_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_2.csv uploaded to train_credit_bureau_a_2_2.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_static_0_1.csv uploaded to train_static_0_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_deposit_1.csv uploaded to train_deposit_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_10.csv uploaded to train_credit_bureau_a_2_10.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_tax_registry_b_1.csv uploaded to train_tax_registry_b_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_applprev_1_1.csv uploaded to train_applprev_1_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_1.csv uploaded to train_credit_bureau_a_2_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_8.csv uploaded to train_credit_bureau_a_2_8.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_5.csv uploaded to train_credit_bureau_a_2_5.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_b_1.csv uploaded to train_credit_bureau_b_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_credit_bureau_a_2_0.csv uploaded to train_credit_bureau_a_2_0.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_other_1.csv uploaded to train_other_1.csv.
# File /kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_debitcard_1.csv uploaded to train_debitcard_1.csv.

# %%
print('Data inside of',bucket_name,':')
list_blobs(bucket_name)
# Out:
# Data inside of baglitech-kaggle-homecredit :
# FileName_ColumnName.xlsx
# Home Credit File Schema.drawio
# hc-rawdata/
# test_applprev_1_0.csv
# test_applprev_1_1.csv
# test_applprev_1_2.csv
# test_applprev_2.csv
# test_base.csv
# test_credit_bureau_a_1_0.csv
# test_credit_bureau_a_1_1.csv
# test_credit_bureau_a_1_2.csv
# test_credit_bureau_a_1_3.csv
# test_credit_bureau_a_1_4.csv
# test_credit_bureau_a_2_0.csv
# test_credit_bureau_a_2_1.csv
# test_credit_bureau_a_2_10.csv
# test_credit_bureau_a_2_11.csv
# test_credit_bureau_a_2_2.csv
# test_credit_bureau_a_2_3.csv
# test_credit_bureau_a_2_4.csv
# test_credit_bureau_a_2_5.csv
# test_credit_bureau_a_2_6.csv
# test_credit_bureau_a_2_7.csv
# test_credit_bureau_a_2_8.csv
# test_credit_bureau_a_2_9.csv
# test_credit_bureau_b_1.csv
# test_credit_bureau_b_2.csv
# test_debitcard_1.csv
# test_deposit_1.csv
# test_other_1.csv
# test_person_1.csv
# test_person_2.csv
# test_static_0_0.csv
# test_static_0_1.csv
# test_static_0_2.csv
# test_static_cb_0.csv
# test_tax_registry_a_1.csv
# test_tax_registry_b_1.csv
# test_tax_registry_c_1.csv
# train_applprev_1_0.csv
# train_applprev_1_1.csv
# train_applprev_2.csv
# train_base.csv
# train_credit_bureau_a_1_0.csv
# train_credit_bureau_a_1_1.csv
# train_credit_bureau_a_1_2.csv
# train_credit_bureau_a_1_3.csv
# train_credit_bureau_a_2_0.csv
# train_credit_bureau_a_2_1.csv
# train_credit_bureau_a_2_10.csv
# train_credit_bureau_a_2_2.csv
# train_credit_bureau_a_2_3.csv
# train_credit_bureau_a_2_4.csv
# train_credit_bureau_a_2_5.csv
# train_credit_bureau_a_2_6.csv
# train_credit_bureau_a_2_7.csv
# train_credit_bureau_a_2_8.csv
# train_credit_bureau_a_2_9.csv
# train_credit_bureau_b_1.csv
# train_credit_bureau_b_2.csv
# train_debitcard_1.csv
# train_deposit_1.csv
# train_other_1.csv
# train_person_1.csv
# train_person_2.csv
# train_static_0_0.csv
# train_static_0_1.csv
# train_static_cb_0.csv
# train_tax_registry_a_1.csv
# train_tax_registry_b_1.csv
# train_tax_registry_c_1.csv
